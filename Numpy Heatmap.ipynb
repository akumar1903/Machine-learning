# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("C:/Users/arunk01/Desktop/Analytics Vidhya/Python/correlation/correlation.csv", encoding = "ISO-8859-1")

# %%
data
# Out:
#      Item_Identifier  Item_Weight  Item_MRP  Item_Outlet_Sales
# 0              FDA15        9.300  249.8092          3735.1380
# 1              DRC01        5.920   48.2692           443.4228
# 2              FDN15       17.500  141.6180          2097.2700
# 3              FDX07       19.200  182.0950           732.3800
# 4              NCD19        8.930   53.8614           994.7052
# 5              FDP36       10.395   51.4008           556.6088
# 6              FDO10       13.650   57.6588           343.5528
# 7              FDP10          NaN  107.7622          4022.7636
# 8              FDH17       16.200   96.9726          1076.5986
# 9              FDU28       19.200  187.8214          4710.5350
# 10             FDY07       11.800   45.5402          1516.0266
# 11             FDA03       18.500  144.1102          2187.1530
# 12             FDX32       15.100  145.4786          1589.2646
# 13             FDS46       17.600  119.6782          2145.2076
# ...

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight  Item_MRP  Item_Outlet_Sales
# 0           FDA15         9.30  249.8092          3735.1380
# 1           DRC01         5.92   48.2692           443.4228
# 2           FDN15        17.50  141.6180          2097.2700
# 3           FDX07        19.20  182.0950           732.3800
# 4           NCD19         8.93   53.8614           994.7052

# %%
data[["Item_Weight","Item_MRP"]].corr()
# Out:
#              Item_Weight  Item_MRP
# Item_Weight     1.000000  0.027141
# Item_MRP        0.027141  1.000000

# %%
data[["Item_Weight","Item_Outlet_Sales"]].corr()
# Out:
#                    Item_Weight  Item_Outlet_Sales
# Item_Weight           1.000000           0.014123
# Item_Outlet_Sales     0.014123           1.000000

# %%
data[["Item_MRP","Item_Outlet_Sales"]].corr()
# Out:
#                    Item_MRP  Item_Outlet_Sales
# Item_MRP           1.000000           0.567574
# Item_Outlet_Sales  0.567574           1.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data.corr()
# Out:
#                    Item_Weight  Item_MRP  Item_Outlet_Sales
# Item_Weight           1.000000  0.027141           0.014123
# Item_MRP              0.027141  1.000000           0.567574
# Item_Outlet_Sales     0.014123  0.567574           1.000000

# %%
cor = data.corr()
plt.figure(figsize=(16,10))
sns.heatmap(cor)

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel("C:/Users/arunk01/Desktop/Analytics Vidhya/Python/covar.xlsx", encoding = "ISO-8859-1")

# %%
data.head()
# Out:
#     X   Y
# 0  43  99
# 1  21  65
# 2  25  79
# 3  42  75
# 4  57  87

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data.corr()
# Out:
#           X         Y
# X  1.000000  0.529809
# Y  0.529809  1.000000

# %%
df = pd.read_csv("C:/Users/arunk01/Desktop/Analytics Vidhya/Python/data_statistics.csv", encoding = "ISO-8859-1")

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df_median = df["Item_MRP"].median()

# %%
df_median
# Out:
# 143.0128

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df_corr = df[['Item_MRP','Item_Outlet_Sales']].corr()

# %%
df_corr
# Out:
#                    Item_MRP  Item_Outlet_Sales
# Item_MRP           1.000000           0.567574
# Item_Outlet_Sales  0.567574           1.000000

# %%
df_corr = df['Item_MRP'].corr(df['Item_Outlet_Sales'])

# %%
df_corr
# Out:
# 0.5675744466569194

# %%
df.corr()
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.014048  0.027141
# Item_Visibility              -0.014048         1.000000 -0.001315
# Item_MRP                      0.027141        -0.001315  1.000000
# Outlet_Establishment_Year    -0.011588        -0.074834  0.005020
# Item_Outlet_Sales             0.014123        -0.128625  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.011588           0.014123
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005020           0.567574
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000

# %%
import scipy.stats as stats
from scipy.stats import ttest_1samp

# %%
df_mean = df["Item_MRP"].mean()

# %%
df_mean
# Out:
# 140.9927819781768

# %%
t_statistic, p_value = ttest_1samp(df["Item_MRP"],140)
p_value
# Out:
# 0.1411236005459367
