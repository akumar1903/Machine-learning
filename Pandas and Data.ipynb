# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/arunk01/Desktop/Analytics Vidhya/Python/FAO.csv",encoding = "ISO-8859-1")

# %%
df
# Out:
#       Area Abbreviation  Area Code         Area  Item Code  \
# 0                    AF          2  Afghanistan       2511
# 1                    AF          2  Afghanistan       2805
# 2                    AF          2  Afghanistan       2513
# 3                    AF          2  Afghanistan       2513
# 4                    AF          2  Afghanistan       2514
# 5                    AF          2  Afghanistan       2514
# 6                    AF          2  Afghanistan       2517
# 7                    AF          2  Afghanistan       2520
# 8                    AF          2  Afghanistan       2531
# 9                    AF          2  Afghanistan       2536
# 10                   AF          2  Afghanistan       2537
# 11                   AF          2  Afghanistan       2542
# 12                   AF          2  Afghanistan       2543
# 13                   AF          2  Afghanistan       2745
# 14                   AF          2  Afghanistan       2549
# ...

# %%
mode_df = df["Area"].mode()

# %%
print(mode_df)
# Out:
# 0    Spain
# dtype: object

# %%
df.head()
# Out:
#   Area Abbreviation  Area Code         Area  Item Code  \
# 0                AF          2  Afghanistan       2511
# 1                AF          2  Afghanistan       2805
# 2                AF          2  Afghanistan       2513
# 3                AF          2  Afghanistan       2513
# 4                AF          2  Afghanistan       2514
#
#                        Item  Element Code Element         Unit  latitude  \
# 0        Wheat and products          5142    Food  1000 tonnes     33.94
# 1  Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
# 2       Barley and products          5521    Feed  1000 tonnes     33.94
# 3       Barley and products          5142    Food  1000 tonnes     33.94
# 4        Maize and products          5521    Feed  1000 tonnes     33.94
#
#    longitude  ...     Y2004   Y2005   Y2006   Y2007   Y2008   Y2009   Y2010  \
# 0      67.71  ...    3249.0  3486.0  3704.0  4164.0  4252.0  4538.0  4605.0
# ...

# %%
mean_df = df["Item Code"].mean()

# %%
print(mean_df)
# Out:
# 2694.2115286120033

# %%
mode_df = df["Item Code"].mode()

# %%
print(mode_df)
# Out:
# 0    2905
# dtype: int64

# %%
median_df = df["Item Code"].median()

# %%
print(median_df)
# Out:
# 2640.0

# %%
Q1 = df["Item Code"].quantile(0.25)
Q2 = df["Item Code"].quantile(0.50)
Q3 = df["Item Code"].quantile(0.75)
Q4 = df["Item Code"].quantile(1.00)

# %%
print(Q1)
print(Q2)
print(Q3)
print(Q4)
# Out:
# 2561.0
# 2640.0
# 2782.0
# 2961.0

# %%
max_df = df["Item Code"].max()

# %%
min_df = df["Item Code"].min()

# %%
range = max_df - min_df

# %%
print(range)
# Out:
# 450

# %%
IQR = Q3 - Q1

# %%
print(IQR)
# Out:
# 221.0

# %%
df_mean = df["Item Code"].mean()

# %%
print(df_mean)
# Out:
# 2694.2115286120033

# %%
df_difference = df["Item Code"] - df_mean

# %%
sq_df_difference = df_difference **2

# %%
variance = sq_df_difference.mean()

# %%
print(variance)
# Out:
# 22192.042372096555

# %%
var_data = df["Item Code"].var(ddof = 0)

# %%
print(var_data)
# Out:
# 22192.042372096555

# %%
list_var = [7,6,8,4,2,7,6,7,6,5]

# %%
variance = list_var[7,6,8,4,2,7,6,7,6,5].var(ddof=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-a7bc4a74e860> in <module>()
# ----> 1 variance = list_var[7,6,8,4,2,7,6,7,6,5].var(ddof=0)
#
# TypeError: list indices must be integers or slices, not tuple

# %%
std = df["Item Code"].std(ddof=0)

# %%
print(std)
# Out:
# 148.96993781329357
